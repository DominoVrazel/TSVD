# %%
import sys
print(f"✅ Notebook is running!")
print(f"Python version: {sys.version}")
print(f"Test successful - notebook execution works correctly")
# Out:
# ✅ Notebook is running!
# Python version: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# Test successful - notebook execution works correctly
